# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.preprocessing import  Imputer
from sklearn.preprocessing import LabelEncoder
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline
from sklearn.pipeline import FeatureUnion
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression

# %%
housing= pd.read_csv('.//datasets//''melb_data.csv')

# %%
housing.hist(figsize=(15,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0804EED0>,
# ...
#       dtype=object)

# %%
housing=housing.drop(['Suburb','Address','SellerG','Date','CouncilArea'],axis=1)

# %%
housing.head()
# Out:
#    Rooms Type      Price Method  Distance  Postcode  Bedroom2  Bathroom  Car  \
# 0      2    h  1480000.0      S       2.5    3067.0       2.0       1.0  1.0
# 1      2    h  1035000.0      S       2.5    3067.0       2.0       1.0  0.0
# 2      3    h  1465000.0     SP       2.5    3067.0       3.0       2.0  0.0
# 3      3    h   850000.0     PI       2.5    3067.0       3.0       2.0  1.0
# 4      4    h  1600000.0     VB       2.5    3067.0       3.0       1.0  2.0
#
#    Landsize  BuildingArea  YearBuilt  Lattitude  Longtitude  \
# 0     202.0           NaN        NaN   -37.7996    144.9984
# 1     156.0          79.0     1900.0   -37.8079    144.9934
# 2     134.0         150.0     1900.0   -37.8093    144.9944
# 3      94.0           NaN        NaN   -37.7969    144.9969
# 4     120.0         142.0     2014.0   -37.8072    144.9941
#
#               Regionname  Propertycount
# 0  Northern Metropolitan         4019.0
# 1  Northern Metropolitan         4019.0
# ...

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 16 columns):
# Rooms            13580 non-null int64
# Type             13580 non-null object
# Price            13580 non-null float64
# Method           13580 non-null object
# Distance         13580 non-null float64
# Postcode         13580 non-null float64
# Bedroom2         13580 non-null float64
# Bathroom         13580 non-null float64
# Car              13518 non-null float64
# Landsize         13580 non-null float64
# BuildingArea     7130 non-null float64
# YearBuilt        8205 non-null float64
# Lattitude        13580 non-null float64
# Longtitude       13580 non-null float64
# Regionname       13580 non-null object
# Propertycount    13580 non-null float64
# dtypes: float64(12), int64(1), object(3)
# memory usage: 1.5+ MB

# %%
housing.isnull().sum().sort_values()
# Out:
# Rooms               0
# Type                0
# Price               0
# Method              0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Landsize            0
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# Car                62
# YearBuilt        5375
# BuildingArea     6450
# dtype: int64

# %%
housing_corr= housing.corr()

# %%
housing_corr['Price'].sort_values(ascending= False)
# Out:
# Price            1.000000
# Rooms            0.496634
# Bedroom2         0.475951
# Bathroom         0.467038
# Car              0.238979
# Longtitude       0.203656
# Postcode         0.107867
# BuildingArea     0.090981
# Landsize         0.037507
# Propertycount   -0.042153
# Distance        -0.162522
# Lattitude       -0.212934
# YearBuilt       -0.323617
# Name: Price, dtype: float64

# %%
housing['Rooms'].max()
# Out:
# 10

# %%
housing['Rooms'].value_counts().sort_values(ascending=False).head(10)
# Out:
# 3     5881
# 2     3648
# 4     2688
# 1      681
# 5      596
# 6       67
# 7       10
# 8        8
# 10       1
# Name: Rooms, dtype: int64

# %%
housing['Rooms'].hist(bins=10)

# %%
housing['Rooms'].unique()
# Out:
# array([ 4,  2,  1,  3,  5,  8,  6, 10,  7], dtype=int64)

# %%
housing['rooms_cat']=np.ceil(housing['Rooms']/2)
housing["rooms_cat"].where(housing["rooms_cat"] < 3, 3.0, inplace=True)

# %%
housing['rooms_cat'].value_counts().unique()
# Out:
# array([8569, 4329,  682], dtype=int64)

# %%
housing['rooms_cat'].hist()

# %%
split= StratifiedShuffleSplit(n_splits=1,test_size=0.2, random_state=42)
for train_index, test_index in split.split(housing, housing['rooms_cat']):
    strat_test_set= housing.loc[test_index]
    strat_train_set= housing.loc[train_index]

# %%
strat_test_set["rooms_cat"].value_counts() / len(strat_test_set)
# Out:
# 2.0    0.631075
# 1.0    0.318851
# 3.0    0.050074
# Name: rooms_cat, dtype: float64

# %%
for set_ in (strat_test_set, strat_train_set):
    set_.drop('rooms_cat', axis=1, inplace= True)

# %%
housing= strat_train_set.copy()

# %%
housing.head()
# Out:
#       Rooms Type      Price Method  Distance  Postcode  Bedroom2  Bathroom  \
# 7396      4    h   950000.0      S      12.5    3041.0       4.0       3.0
# 1698      2    u   570000.0      S       3.2    3054.0       2.0       1.0
# 4889      4    h  1082000.0      S       8.8    3072.0       4.0       2.0
# 2493      4    h  1160000.0     PI       5.8    3078.0       4.0       2.0
# 8007      2    h   690000.0     VB       7.9    3079.0       2.0       1.0
#
#       Car  Landsize  BuildingArea  YearBuilt  Lattitude  Longtitude  \
# 7396  2.0     541.0           NaN        NaN   -37.7156    144.8975
# 1698  1.0       0.0          76.0     1975.0   -37.7902    144.9700
# 4889  3.0     534.0           NaN        NaN   -37.7339    145.0189
# 2493  1.0     381.0         145.0     1890.0   -37.7735    145.0192
# 8007  1.0    1465.0           NaN        NaN   -37.7735    145.0403
#
#                  Regionname  Propertycount
# 7396   Western Metropolitan          389.0
# ...

# %%
housing.columns
# Out:
# Index(['Rooms', 'Type', 'Price', 'Method', 'Distance', 'Postcode', 'Bedroom2',
#        'Bathroom', 'Car', 'Landsize', 'BuildingArea', 'YearBuilt', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
housing.plot(kind="scatter", x='Longtitude', y='Lattitude', alpha= 0.1)

# %%
housing.plot(kind="scatter", x='Longtitude', y='Lattitude', alpha=0.4,
s=housing["Rooms"], label="Rooms", figsize=(10,7),
c="Price", cmap=plt.get_cmap("jet"), colorbar=True,)
plt.legend()

# %%
sns.kdeplot(housing['Price'])
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.jointplot(y=housing['Price'], x=housing['Rooms'],kind='kde', color='g')
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
housing_corr['Rooms'].sort_values(ascending= False)
# Out:
# Rooms            1.000000
# Bedroom2         0.944190
# Bathroom         0.592934
# Price            0.496634
# Car              0.408483
# Distance         0.294203
# BuildingArea     0.124127
# Longtitude       0.100771
# Postcode         0.055303
# Landsize         0.025678
# Lattitude        0.015948
# YearBuilt       -0.065413
# Propertycount   -0.081530
# Name: Rooms, dtype: float64

# %%
housing.plot.scatter(x='Rooms', y='Bedroom2',c='DarkBlue')

# %%
corr_matrix= housing.corr()

# %%
corr_matrix['Bedroom2'].sort_values(ascending=False)
# Out:
# Bedroom2         1.000000
# Rooms            0.955225
# Bathroom         0.596672
# Price            0.478596
# Car              0.409665
# Distance         0.298041
# BuildingArea     0.115923
# Longtitude       0.102429
# Postcode         0.055869
# Landsize         0.025266
# Lattitude        0.018785
# YearBuilt       -0.054031
# Propertycount   -0.086765
# Name: Bedroom2, dtype: float64

# %%
housing= strat_train_set.drop('Price', axis=1)
housing_labels=strat_train_set['Price'].copy()

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10864 entries, 7396 to 6924
# Data columns (total 15 columns):
# Rooms            10864 non-null int64
# Type             10864 non-null object
# Method           10864 non-null object
# Distance         10864 non-null float64
# Postcode         10864 non-null float64
# Bedroom2         10864 non-null float64
# Bathroom         10864 non-null float64
# Car              10812 non-null float64
# Landsize         10864 non-null float64
# BuildingArea     5737 non-null float64
# YearBuilt        6598 non-null float64
# Lattitude        10864 non-null float64
# Longtitude       10864 non-null float64
# Regionname       10864 non-null object
# Propertycount    10864 non-null float64
# dtypes: float64(11), int64(1), object(3)
# memory usage: 1.2+ MB

# %%
housing.columns
# Out:
# Index(['Rooms', 'Type', 'Method', 'Distance', 'Postcode', 'Bedroom2',
#        'Bathroom', 'Car', 'Landsize', 'BuildingArea', 'YearBuilt', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
imputer= Imputer(strategy='median')

# %%
housing_num=housing.drop(['Type','Method','Regionname'], axis=1)

# %%
imputer.fit(housing_num)
# Out:
# Imputer(axis=0, copy=True, missing_values='NaN', strategy='median', verbose=0)

# %%
imputer.statistics_
# Out:
# array([ 3.00000000e+00,  9.20000000e+00,  3.08400000e+03,  3.00000000e+00,
#         1.00000000e+00,  2.00000000e+00,  4.40500000e+02,  1.25000000e+02,
#         1.97000000e+03, -3.78035000e+01,  1.45000225e+02,  6.56700000e+03])

# %%
housing_num.median().values
# Out:
# array([ 3.00000000e+00,  9.20000000e+00,  3.08400000e+03,  3.00000000e+00,
#         1.00000000e+00,  2.00000000e+00,  4.40500000e+02,  1.25000000e+02,
#         1.97000000e+03, -3.78035000e+01,  1.45000225e+02,  6.56700000e+03])

# %%
x= imputer.transform(housing_num)

# %%
housing_tr= pd.DataFrame(x, columns=housing_num.columns )

# %%
housing_cat=housing[['Type', 'Method','Regionname']]

# %%
housing_cat['Type'].value_counts().sort_values(ascending=False).head(3)
# Out:
# h    7549
# u    2425
# t     890
# Name: Type, dtype: int64

# %%
housing_cat.head()
# Out:
#      Type Method             Regionname
# 7396    h      S   Western Metropolitan
# 1698    u      S  Northern Metropolitan
# 4889    h      S  Northern Metropolitan
# 2493    h     PI  Northern Metropolitan
# 8007    h     VB   Eastern Metropolitan

# %%
housing_cat['Method'].value_counts().sort_values(ascending=False).head()
# Out:
# S     7200
# SP    1371
# PI    1249
# VB     969
# SA      75
# Name: Method, dtype: int64

# %%
housing_cat['Regionname'].value_counts().sort_values(ascending=False).head()
# Out:
# Southern Metropolitan         3801
# Northern Metropolitan         3055
# Western Metropolitan          2384
# Eastern Metropolitan          1164
# South-Eastern Metropolitan     362
# Name: Regionname, dtype: int64

# %%
lbl= LabelEncoder()

# %%
housing_cat['Regionname']= lbl.fit_transform(housing_cat['Regionname'])
housing_cat['Method']= lbl.fit_transform(housing_cat['Method'])
housing_cat['Type']= lbl.fit_transform(housing_cat['Type'])
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\DELL\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\DELL\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
rooms_ix, bedrooms_ix = 3, 4 
class CombinedAttributesAdder(BaseEstimator,TransformerMixin):
   def __init__(self, add_bedrooms_per_room = True):
    self.add_Bedrooms_per_room= add_bedrooms_per_room
   def fit(self,X,y=None):
        return self
   def transform(self, X, y=None):
        if self.add_Bedrooms_per_room:
            Bedrooms_per_room = X[:, bedrooms_ix] / X[ : , rooms_ix]
            return np.c[Bedrooms_per_room]
        else:
            return[X]

# %%
num_pipeline=Pipeline([
    ('imputer', Imputer(strategy='median')),
    ('std_scaler',StandardScaler()),
])

# %%
housing_num_tr= num_pipeline.fit_transform(housing_num)

# %%
class DataFrameSelector(BaseEstimator, TransformerMixin):
    def __init__(self, attribute_names):
        self.attribute_names = attribute_names
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        return X[self.attribute_names].values

# %%
num_attr= list(housing_num)
cat_attr= list(housing_cat)

# %%
num_pipeline= Pipeline([
    ('selector', DataFrameSelector(num_attr)),
    ('imputer', Imputer(strategy='median')),
    ('std_scaler', StandardScaler()),
])

# %%
cat_pipeline= Pipeline([
    ('selector', DataFrameSelector(cat_attr)),
    ('lbl', LabelEncoder()),
])

# %%
full_pipeline=FeatureUnion(transformer_list=[
    ('num_pipeline',num_pipeline),
    ('cat_pipeline', cat_pipeline)
])
